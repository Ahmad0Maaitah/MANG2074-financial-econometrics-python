# %% [markdown]
# # Week 12 — Mock Coursework: An Empirical Finance Project
#
# **MANG2074 Financial Econometrics 1**
#
# This notebook mirrors the structure of the assessed empirical project (3000-word style). Treat each part as a section of your report: code, results, then a written interpretation in the markdown cell provided.
#
# **Brief.** You are a junior analyst. Produce an empirical report covering:
#
# - **Part A — Data and stylised facts**: construct returns, descriptive statistics, normality.
# - **Part B — Asset pricing**: a CAPM study of General Electric (2002–2018) with full diagnostics and a 2008 structural-break test.
# - **Part C — Forecasting**: Box–Jenkins ARMA modelling and a 12-month forecast of UK house-price growth.
# - **Part D — Risk**: GARCH modelling of GBP/USD and a 1% one-day parametric VaR for a £5m position.
#
# **Data**: `../data/capm.csv`, `../data/ukhp.csv`, `../data/currencies.csv`.

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.tsa.stattools import adfuller, acf, pacf
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.stats.diagnostic import (het_breuschpagan, het_white,
                                          acorr_breusch_godfrey, linear_reset, het_arch)
from statsmodels.stats.stattools import jarque_bera, durbin_watson
from arch import arch_model
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

capm = pd.read_csv('../data/capm.csv', index_col=0, parse_dates=True)
hp = pd.read_csv('../data/ukhp.csv', index_col=0, parse_dates=True).asfreq('MS')
fx = pd.read_csv('../data/currencies.csv', index_col=0, parse_dates=True)
print('loaded:', capm.shape, hp.shape, fx.shape)

# %% [markdown]
# ## Part A — Data and stylised facts
#
# ### Task A1
#
# Construct: GE and S&P excess returns from `capm.csv` (log returns minus `USTB3M/12`); house-price growth `dhp` from `ukhp.csv`; GBP log returns from `currencies.csv`. For each: n, mean, std, skewness, excess kurtosis, JB test. Present as one table and interpret (2–3 sentences in the markdown cell).

# %%
capm['erge'] = 100 * np.log(capm['GE']).diff() - capm['USTB3M'] / 12
# YOUR CODE HERE: ersandp, dhp, rgbp + the summary table with JB

# %% [markdown]
# *YOUR INTERPRETATION HERE*

# %% [markdown]
# ## Part B — CAPM study of General Electric
#
# ### Task B1 — Estimation and hypothesis tests
#
# Estimate $er_{GE,t} = \alpha + \beta\, er_{M,t} + u_t$. Test: (i) $\beta=0$; (ii) $\beta=1$; (iii) $\alpha=0$. Interpret each in CAPM language.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task B2 — Diagnostic battery
#
# Run and tabulate: Breusch–Pagan, White, Durbin–Watson, Breusch–Godfrey (12 lags), Jarque–Bera (residuals), RESET. Where a test rejects, state the consequence and apply the remedy (robust or Newey–West SEs) and report whether conclusions change.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task B3 — Structural stability
#
# Chow test at January 2008; report pre/post betas and the F-statistic. Connect the result to what happened to GE (hint: GE Capital).

# %%
# YOUR CODE HERE

# %% [markdown]
# *YOUR PART B WRITE-UP HERE (~200 words)*

# %% [markdown]
# ## Part C — Forecasting UK house-price growth
#
# ### Task C1 — Identification and estimation
#
# ADF test on `dhp`; correlogram; estimate the BIC-preferred ARMA from a small candidate set (include AR(2)); residual Ljung–Box.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task C2 — Forecast
#
# Produce and plot a 12-month dynamic forecast with 95% intervals (`res.get_forecast(12)`, `.predicted_mean`, `.conf_int()`). What does the forecast converge to?

# %%
# YOUR CODE HERE

# %% [markdown]
# *YOUR PART C WRITE-UP HERE (~150 words)*

# %% [markdown]
# ## Part D — GARCH risk model for sterling
#
# ### Task D1 — ARCH effects and GARCH estimation
#
# ARCH-LM test on GBP returns; estimate GARCH(1,1) with normal and Student-t errors; report persistence and $\hat\nu$; plot conditional volatility (annotate Brexit, June 2016).

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task D2 — Value-at-Risk
#
# Compute the 1% one-day parametric VaR for a **£5m** GBP position under both distributions, using the one-step volatility forecast. Recommend one number to the desk and defend it.

# %%
# YOUR CODE HERE

# %% [markdown]
# *YOUR PART D WRITE-UP HERE (~150 words)*

# %% [markdown]
# ## Final task — Executive summary
#
# Write a ~150-word executive summary of the whole report: one finding per part, with numbers.

# %% [markdown]
# *YOUR EXECUTIVE SUMMARY HERE*
